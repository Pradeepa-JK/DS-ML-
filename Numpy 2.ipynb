# %%
import numpy as np 
a=np.array([1,2,3,4,5])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
print(np.where(a>3))
# Out:
# (array([3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 1  3  6 10 15]

# %%
r=np.random.randint(1,20,10)
r
# Out:
# array([ 1,  7, 11, 11,  6, 11,  8, 13, 12, 12])

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(np.corrcoef(a,b))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
a=np.array([1,2,3,4,5])
np.save("ps.npy",a)
print(np.load("ps.npy"))
# Out:
# [1 2 3 4 5]

# %%
a=np.array([1,2,3,4,5])
print(a[2:4])
# Out:
# [3 4]

# %%
print(a[::3])
# Out:
# [1 4]

# %%
print(a[::-2])
# Out:
# [5 3 1]

# %%
print(a[:-2])
# Out:
# [1 2 3]

# %%
arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,2]])
print(arr[0:1,1:3])
# Out:
# [[2 3]]

# %%
print(arr[:,::2])
# Out:
# [[1 3]
#  [3 5]
#  [7 9]]

# %%
print(arr[:,1:2])
# Out:
# [[2]
#  [4]
#  [8]]
