# %%
from scipy.stats import binom

# %%
#probability distribution
# binomial distribution
#Q-1
#n - no of trails
#k-no of sucess
#p-probability of success on given trail
binom.pmf(n=12,k=10,p=.6)
#PMF-Probability mass function
# Out:
# np.float64(0.06385228185600002)

# %%
# question 2
binom.pmf(n=5,k=2,p=.5)
# Out:
# np.float64(0.31249999999999983)

# %%
binom.pmf(n=5,k=1,p=.5)
# Out:
# np.float64(0.15624999999999997)

# %%
binom.pmf(n=5,k=0,p=.5)
# Out:
# np.float64(0.031249999999999976)

# %%
# CDF - cumulation distribution function
binom.cdf(n=5,k=2,p=.5)
# Out:
# np.float64(0.5)

# %%
#normal distribution
# Q-3
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
a=np.random.normal(loc=0,scale=1,size=100)
plt.hist(a,bins=15)
plt.title("Normal distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(a,orientation='horizontal')
plt.title("Normal distribution")
plt.show()

# %%
sns.histplot(a,kde=True)
plt.title("Normal distribution Curve ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
