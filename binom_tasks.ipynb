# %%
from scipy.stats import binom
#probability distribution
# binomial distribution
#Q-1
#n - no of trails
#k-no of sucess
#p-probability of success on given trail

# %%
#p=.9
#n=12
#k=10
binom.pmf(n=12,k=10,p=.9)
# Out:
# np.float64(0.23012777046599997)

# %%
a=binom.pmf(n=12,k=11,p=.9)
b=binom.pmf(n=12,k=12,p=.9)
c=a+b
print(c)
# Out:
# 0.6590022517890002

# %%
#atleast 11
binom.sf(n=12,k=10,p=.9)
# Out:
# np.float64(0.6590022517890002)

# %%
# fewer than 9
binom.cdf(n=12,k=8,p=.9)
# Out:
# np.float64(0.02563747016499998)

# %%
#2 65%students placed
#p=65%
#n=15
#exactly 12
#atleast 10
exact=binom.pmf(n=15,k=12,p=.65)
print("exactly 12 :",exact)
atleast=binom.sf(n=15,k=9,p=.65)
print("Atleast 10 : ",atleast)
n=15
p=.65
e=n*p
print("expected",e)
# Out:
# exactly 12 : 0.11096239180419934
# Atleast 10 :  0.5642821112643028
# expected 9.75

# %%
import numpy as np

# %%
#3 70% loan approval
#n=20
#p=.7
#exactly 16
exact=binom.pmf(n=20,k=16,p=.7)
print("exactly 16 :",exact)
#more than 18
more=binom.sf(n=20,k=18,p=.7)
print("more than 18 :",more)
n=20
p=.7
e=n*p
q=1-p
print("expected :",e)
varience=(n*p*q)
print("varience",varience)
# Out:
# exactly 16 : 0.1304209743738704
# more than 18 : 0.007637259774199997
# expected : 14.0
# varience 4.200000000000001

# %%
#4 40% hitting
#n=10
#exactly 5
exact=binom.pmf(n=10,k=5,p=.4)
print("exactly 5 :",exact)
#atleast 7
atleast=binom.sf(n=10,k=6,p=.4)
print("atleast 7 :",atleast)
# no boundries 0
no=binom.pmf(n=10,k=0,p=.4)
print("no boundries :",no)
# Out:
# exactly 5 : 0.20065812479999992
# atleast 7 : 0.05476188160000002
# no boundries : 0.0060466175999999185

# %%
#5 bulbs 5% defect rates
#n=30
#exactly 2 defective bulbs
exact=binom.pmf(n=30,k=2,p=.05)
print("exactly 2 defective bulbs :",exact)
#none defective
none=binom.pmf(n=30,k=0,p=.05)
print("none defective :",none)
#atleast 1 defective
atleast=binom.sf(n=30,k=0,p=.05)
print("atleast 1 defective :",atleast
# Out:
# exactly 2 defective bulbs : 0.25863673771517404
# none defective : 0.21463876394293752
# atleast 1 defective : 0.7853612360570624

# %%
#6 25% clicks mail
#n=18
#exactly 6
exact=binom.pmf(n=18,k=6,p=.25)
print("exactly 6 :",exact)
#atleast=4
atleast=binom.sf(n=18,k=3,p=.25)
print("atleast 4 :",atleast)
#expected
expected=binom.sf(n=18,k=0,p=.25)
n=18
p=.25
print("expected :",n*p)
# Out:
# exactly 6 : 0.1435644040466287
# atleast 4 : 0.6943108293926343
# expected : 4.5

# %%
#7 vaccine effective in 95%
#n=25
#exactly=24
exactly=binom.pmf(n=25,k=24,p=.95)
print("exactly 20 :",exactly)
#all 25
all=binom.pmf(n=25,k=25,p=.95)
print("all 25 :",all)
#fewer than 23
fewer=binom.cdf(n=25,k=22,p=.95)
print("fewer than 23 :",fewer)
# Out:
# exactly 20 : 0.3649862804234658
# all 25 : 0.27738957312183377
# fewer than 23 : 0.12710649566093235

# %%
#8 92% test case pass
#n=20
#exactly=18
exactly=binom.pmf(n=20,k=18,p=.92)
print("exactly 18 :",exactly)
#all test case
all=binom.pmf(n=20,k=20,p=.92)
print("all test case :",all)
#at least 19
atleast=binom.sf(n=20,k=18,p=.92)
print("at least 19 :",atleast)
# Out:
# exactly 18 : 0.2710906052244336
# all test case : 0.1886933291627967
# at least 19 : 0.5168556407502689

# %%
#9 classes attend=0.8
#n=15
# exactly 12
exactly=binom.pmf(n=15,k=12,p=.8)
print("exactly 12 :",exactly)
#more than 10
more=binom.sf(n=15,k=10,p=.8)
print("more than 10 :",more)
#expected all
n=15
p=.8
print("expected :",n*p)
# Out:
# exactly 12 : 0.25013889531904
# more than 10 : 0.8357662760632321
# expected : 12.0

# %%
#10  ad convinces 30% to install app
#n=25
#exactly=8
exactly=binom.pmf(n=25,k=8,p=.3)
print("exactly 8 :",exactly)
#atleast 10
atleast=binom.sf(n=25,k=9,p=.3)
print("atleast 10 :",atleast)
#fewer 5
few=binom.cdf(n=25,k=4,p=.3)
print("fewer tha3n 5 :",few)
# Out:
# exactly 8 : 0.1650795811315247
# atleast 10 : 0.18943602350494537
# fewer tha3n 5 : 0.09047191855413642
