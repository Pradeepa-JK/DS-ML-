# %%
import numpy as np
from scipy.stats import

# %%
marks = [40, 50, 60, 70, 80]
result=zscore(marks)
print("Z-Scores:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 marks = [40, 50, 60, 70, 80]
# ----> 2 result=zscore(marks)
#       3 print("Z-Scores:", result)
#
# NameError: name 'zscore' is not defined
